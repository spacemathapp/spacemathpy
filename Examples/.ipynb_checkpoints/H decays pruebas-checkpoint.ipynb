# %%
import spacemathpy as spm

# %%
import numpy as np
import matplotlib.pyplot as plt
#%matplotlib qt
# %matplotlib inline
import sympy as sp
sp.init_printing()

# %%
s = 'symbol'
v = 'value'
ghtt,ghbb = sp.symbols('g_{htt},g_{hbb}',positive=True)

# %%
xt = lambda mS: 4*spm.mt[s]**2/(mS**2)
xb = lambda mS: 4*spm.mb[s]**2/(mS**2)
At = lambda mS: sp.asin(sp.sqrt((mS**2)/(4*spm.mt[s]**2)))**2
Ab = lambda mS: -(sp.S(1)/4)*(sp.log((1+sp.sqrt(1-xb(mS)))/(1-sp.sqrt(1-xb(mS))))-sp.I*sp.pi)**2

# %%
Fb = lambda mS:-2*xb(mS)*(1+(1-xb(mS))*Ab(mS))
Ft = lambda mS:-2*xt(mS)*(1+(1-xt(mS))*At(mS))

# %%
AHgg = lambda ghtt,ghbb,mS: 2*spm.mW[s]*((ghtt/(spm.mt[s])*Ft(mS))+(ghbb/(spm.mb[s])*Fb(mS)))

# %%
Whgg = ((spm.αs[s]**2*spm.mh[s]**3)/(512*spm.mW[s]**2*sp.pi**3 ))*(
    AHgg(ghtt,ghbb,spm.mh[s]))**2
Whgg
# Out:
#
#              │                ⎛
#              │                ⎜               ⎛   ⎛      ______________    ⎞
#              │                ⎜               ⎜   ⎜     ╱        2         ⎟
#              │                ⎜               ⎜   ⎜    ╱    4⋅m_b          ⎟
#              │                ⎜               ⎜   ⎜   ╱   - ────── + 1  + 1⎟
#              │                ⎜⎛       2    ⎞ ⎜   ⎜  ╱         2           ⎟
#              │                ⎜⎜  4⋅m_b     ⎟ ⎜   ⎜╲╱        mₕ            ⎟
#              │                ⎜⎜- ────── + 1⎟⋅⎜log⎜────────────────────────⎟ -
#              │                ⎜⎜     2      ⎟ ⎜   ⎜          ______________⎟
#              │                ⎜⎝   mₕ       ⎠ ⎜   ⎜         ╱        2     ⎟
#              │                ⎜               ⎜   ⎜        ╱    4⋅m_b      ⎟
#              │                ⎜               ⎜   ⎜1 -    ╱   - ────── + 1 ⎟
#              │                ⎜               ⎜   ⎜      ╱         2       ⎟
#              │                ⎜               ⎝   ⎝    ╲╱        mₕ        ⎠
#              │  8⋅g_{hbb}⋅m_b⋅⎜───────────────────────────────────────────────
#        2   3 │                ⎝                          4
# \alphaₛ ⋅mₕ ⋅│- ──────────────────────────────────────────────────────────────
#              │                                       2
#              │                                     mₕ
# ──────────────────────────────────────────────────────────────────────────────
#                                                                       3
#                                                                  128⋅π
#
#                                                          2
#      2    ⎞                                             │
#     ⎞     ⎟                                             │
#     ⎟     ⎟                                             │
#     ⎟     ⎟                                             │
#     ⎟     ⎟                                             │
#     ⎟     ⎟                                             │
#     ⎟     ⎟                                             │
#  ⅈ⋅π⎟     ⎟                                             │
#     ⎟     ⎟                                             │
#     ⎟     ⎟                                             │
#     ⎟     ⎟                                             │
#     ⎟     ⎟                ⎛⎛        2⎞                ⎞│
#     ⎟     ⎟                ⎜⎜    4⋅mₜ ⎟     2⎛ mₕ ⎞    ⎟│
#     ⎠     ⎟   8⋅g_{htt}⋅mₜ⋅⎜⎜1 - ─────⎟⋅asin ⎜────⎟ + 1⎟│
# ────── - 1⎟                ⎜⎜       2 ⎟      ⎝2⋅mₜ⎠    ⎟│
#           ⎠                ⎝⎝     mₕ  ⎠                ⎠│
# ─────────── + ──────────────────────────────────────────│
#                                    2                    │
#                                  mₕ                     │
# ──────────────────────────────────────────────────────────

# %%
Whgg.expand()
# Out:
#
#              │                   ⎛        ______________
#              │                   ⎜       ╱        2
#              │                   ⎜      ╱    4⋅m_b
#              │                   ⎜     ╱   - ────── + 1
#              │                   ⎜    ╱         2
#              │             3    2⎜  ╲╱        mₕ                        1
#              │8⋅g_{hbb}⋅m_b ⋅log ⎜──────────────────────── + ─────────────────
#              │                   ⎜          ______________             _______
#              │                   ⎜         ╱        2                 ╱
#              │                   ⎜        ╱    4⋅m_b                 ╱    4⋅m_
#              │                   ⎜1 -    ╱   - ────── + 1    1 -    ╱   - ────
#              │                   ⎜      ╱         2                ╱         2
#        2   3 │                   ⎝    ╲╱        mₕ               ╲╱        mₕ
# \alphaₛ ⋅mₕ ⋅│────────────────────────────────────────────────────────────────
#              │                                    4
#              │                                  mₕ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#        ⎞                          ⎛        ______________
#        ⎟                          ⎜       ╱        2
#        ⎟                          ⎜      ╱    4⋅m_b
#        ⎟                          ⎜     ╱   - ────── + 1
#        ⎟                          ⎜    ╱         2
#        ⎟                     3    ⎜  ╲╱        mₕ                        1
# ───────⎟   16⋅ⅈ⋅π⋅g_{hbb}⋅m_b ⋅log⎜──────────────────────── + ────────────────
# _______⎟                          ⎜          ______________             ______
#  2     ⎟                          ⎜         ╱        2                 ╱
# b      ⎟                          ⎜        ╱    4⋅m_b                 ╱    4⋅m
# ── + 1 ⎟                          ⎜1 -    ╱   - ────── + 1    1 -    ╱   - ───
#        ⎟                          ⎜      ╱         2                ╱
#        ⎠                          ⎝    ╲╱        mₕ               ╲╱        mₕ
# ──────── - ───────────────────────────────────────────────────────────────────
#                                                  4
#                                                mₕ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#         ⎞                                         ⎛        ______________
#         ⎟                                         ⎜       ╱        2
#         ⎟                                         ⎜      ╱    4⋅m_b
#         ⎟                                         ⎜     ╱   - ────── + 1
#         ⎟                                         ⎜    ╱         2
#         ⎟                                        2⎜  ╲╱        mₕ
# ────────⎟                       2⋅g_{hbb}⋅m_b⋅log ⎜──────────────────────── +
# ________⎟                                         ⎜          ______________
#   2     ⎟                                         ⎜         ╱        2
# _b      ⎟                                         ⎜        ╱    4⋅m_b
# ─── + 1 ⎟                                         ⎜1 -    ╱   - ────── + 1
# 2       ⎟      2            3                     ⎜      ╱         2
#         ⎠   8⋅π ⋅g_{hbb}⋅m_b                      ⎝    ╲╱        mₕ
# ───────── - ───────────────── - ──────────────────────────────────────────────
#                      4                                              2
#                    mₕ                                             mₕ
# ──────────────────────────────────────────────────────────────────────────────
#                                                                     3
#                                                                128⋅π
#
#
#                         ⎞                        ⎛        ______________
#                         ⎟                        ⎜       ╱        2
#                         ⎟                        ⎜      ╱    4⋅m_b
#                         ⎟                        ⎜     ╱   - ────── + 1
#                         ⎟                        ⎜    ╱         2
#            1            ⎟                        ⎜  ╲╱        mₕ
# ────────────────────────⎟   4⋅ⅈ⋅π⋅g_{hbb}⋅m_b⋅log⎜──────────────────────── + ─
#           ______________⎟                        ⎜          ______________
#          ╱        2     ⎟                        ⎜         ╱        2
#         ╱    4⋅m_b      ⎟                        ⎜        ╱    4⋅m_b
# 1 -    ╱   - ────── + 1 ⎟                        ⎜1 -    ╱   - ────── + 1    1
#       ╱         2       ⎟                        ⎜      ╱         2
#     ╲╱        mₕ        ⎠                        ⎝    ╲╱        mₕ
# ───────────────────────── + ──────────────────────────────────────────────────
#                                                                  2
#                                                                mₕ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                        ⎞
#                        ⎟
#                        ⎟
#                        ⎟
#                        ⎟
#           1            ⎟
# ───────────────────────⎟
#          ______________⎟
#         ╱        2     ⎟
#        ╱    4⋅m_b      ⎟
#  -    ╱   - ────── + 1 ⎟
#      ╱         2       ⎟                      2               8⋅g_{htt}⋅mₜ⋅asi
#    ╲╱        mₕ        ⎠   8⋅g_{hbb}⋅m_b   2⋅π ⋅g_{hbb}⋅m_b
# ──────────────────────── + ───────────── + ──────────────── + ────────────────
#                                   2                2                      2
#                                 mₕ               mₕ                     mₕ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                      2
#                                                     │
#                                                     │
#                                                     │
#                                                     │
#                                                     │
#                                                     │
#                                                     │
#                                                     │
#                                                     │
#                                                     │
#  2⎛ mₕ ⎞                               3     2⎛ mₕ ⎞│
# n ⎜────⎟                  32⋅g_{htt}⋅mₜ ⋅asin ⎜────⎟│
#   ⎝2⋅mₜ⎠   8⋅g_{htt}⋅mₜ                       ⎝2⋅mₜ⎠│
# ──────── + ──────────── - ──────────────────────────│
#                  2                     4            │
#                mₕ                    mₕ             │
# ──────────────────────────────────────────────────────
